# %%
print("hello world")
# Out:
# hello world

# %%
# %scala 
println("Hey Run scala")
// Magic command
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Hey Run scala
# </div>

# %%
# %sql
select "Run SQL"
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Run SQL</th></tr></thead><tbody><tr><td>Run SQL</td></tr></tbody></table></div>

# %%
# Three level namespace
# catalog.database.objectName

# %%
# %sql
create database if not exists test
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
create or replace table demp(id int, name string)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
show tables
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>tableName</th><th>isTemporary</th></tr></thead><tbody><tr><td>test</td><td>demp</td><td>false</td></tr><tr><td>test</td><td>emp_table</td><td>false</td></tr><tr><td>test</td><td>export_table</td><td>false</td></tr><tr><td></td><td>display_query_1</td><td>true</td></tr></tbody></table></div>

# %%
# %sql
show databases
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>databaseName</th></tr></thead><tbody><tr><td>default</td></tr><tr><td>test</td></tr></tbody></table></div>

# %%
# %sql
use test
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
show tables
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>tableName</th><th>isTemporary</th></tr></thead><tbody><tr><td>test</td><td>demp</td><td>false</td></tr><tr><td>test</td><td>emp_table</td><td>false</td></tr><tr><td>test</td><td>export_table</td><td>false</td></tr><tr><td></td><td>display_query_1</td><td>true</td></tr></tbody></table></div>

# %%
# %sql
create or replace table demp(id int, name string)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql 
show tables
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>tableName</th><th>isTemporary</th></tr></thead><tbody><tr><td>test</td><td>demp</td><td>false</td></tr><tr><td>test</td><td>emp_table</td><td>false</td></tr><tr><td>test</td><td>export_table</td><td>false</td></tr><tr><td></td><td>display_query_1</td><td>true</td></tr></tbody></table></div>

# %%
# %sql
create catalog dev
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# com.databricks.backend.common.rpc.SparkDriverExceptions$SQLExecutionException: org.apache.spark.sql.AnalysisException: [UC_NOT_ENABLED] Unity Catalog is not enabled on this cluster.
# 	at com.databricks.sql.managedcatalog.ManagedCatalogErrors$.unityCatalogNotEnabled(ManagedCatalogErrors.scala:120)
# 	at com.databricks.sql.managedcatalog.ExceptionManagedCatalog.createCatalog(ExceptionManagedCatalog.scala:69)
# 	at com.databricks.sql.managedcatalog.ManagedCatalogSessionCatalog.createCatalog(ManagedCatalogSessionCatalog.scala:418)
# 	at com.databricks.sql.managedcatalog.command.CreateCatalogCommand.run(CatalogCommands.scala:46)
# ...

# %%
users=[(1,'a',30,"Sales"),(2,'b',25,"IT"),(3,'c',28,"Data Science")]
schema="id int, name string, age int, dept string"
df=spark.createDataFrame(users,schema=schema)

# %%
df.show()
# Out:
# +---+----+---+------------+
# | id|name|age|        dept|
# +---+----+---+------------+
# |  1|   a| 30|       Sales|
# |  2|   b| 25|          IT|
# |  3|   c| 28|Data Science|
# +---+----+---+------------+

# %%
df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th><th>age</th><th>dept</th></tr></thead><tbody><tr><td>1</td><td>a</td><td>30</td><td>Sales</td></tr><tr><td>2</td><td>b</td><td>25</td><td>IT</td></tr><tr><td>3</td><td>c</td><td>28</td><td>Data Science</td></tr></tbody></table></div>

# %%
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th><th>age</th><th>dept</th></tr></thead><tbody><tr><td>1</td><td>a</td><td>30</td><td>Sales</td></tr><tr><td>2</td><td>b</td><td>25</td><td>IT</td></tr><tr><td>3</td><td>c</td><td>28</td><td>Data Science</td></tr></tbody></table></div>

# %%
from pyspark.sql.functions import *

# %%
df1=df.withColumnRenamed("id","emp_id").withColumn("current_date",current_date())

# %%
df1.show()
# Out:
# +------+----+---+------------+------------+
# |emp_id|name|age|        dept|current_date|
# +------+----+---+------------+------------+
# |     1|   a| 30|       Sales|  2023-09-26|
# |     2|   b| 25|          IT|  2023-09-26|
# |     3|   c| 28|Data Science|  2023-09-26|
# +------+----+---+------------+------------+

# %%
# Task to save df1 to table in test scehma
# df1.write \
#     .format("parquet") \
#     .mode("overwrite") \
#     .option("path", "test.db/emp_table") \
#     .saveAsTable("test.emp_table")

# This is how it should be done
df1.write.mode("overwrite").saveAsTable("test.emp_table")
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# File <command-558549734154387>, line 9
#       1 # Task to save df1 to table in test scehma
#       2 # df1.write \
#       3 #     .format("parquet") \
#    (...)
#       7
#       8 # This is how it should be done
# ----> 9 df1.write.mode("overwrite").saveAsTable("test.emp_table")
#
# File /databricks/spark/python/pyspark/instrumentation_utils.py:48, in _wrap_function.<locals>.wrapper(*args, **kwargs)
#      46 start = time.perf_counter()
#      47 try:
# ---> 48     res = func(*args, **kwargs)
#      49     logger.log_success(
#      50         module_name, class_name, function_name, time.perf_counter() - start, signature
#      51     )
#      52     return res
#
# File /databricks/spark/python/pyspark/sql/readwriter.py:1586, in DataFrameWriter.saveAsTable(self, name, format, mode, partitionBy, **options)
# ...

# %%
# %sql
use test
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
show tables
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>tableName</th><th>isTemporary</th></tr></thead><tbody><tr><td>test</td><td>demp</td><td>false</td></tr><tr><td>test</td><td>emp_table</td><td>false</td></tr><tr><td>test</td><td>export_table</td><td>false</td></tr><tr><td></td><td>display_query_1</td><td>true</td></tr></tbody></table></div>

# %%
# %sql
select * from emp_table
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>age</th><th>dept</th><th>current_date</th></tr></thead><tbody><tr><td>3</td><td>c</td><td>28</td><td>Data Science</td><td>2023-09-26</td></tr><tr><td>1</td><td>a</td><td>30</td><td>Sales</td><td>2023-09-26</td></tr><tr><td>2</td><td>b</td><td>25</td><td>IT</td><td>2023-09-26</td></tr></tbody></table></div>

# %% [markdown]
# ### DataFrame using Catalog

# %%
# %fs ls
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %fs ls
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %fs ls dbfs:/FileStore/tables
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/FileStore/tables/export.csv</td><td>export.csv</td><td>60</td><td>1695710104000</td></tr></tbody></table></div>

# %%
df = spark.read.option("header",True).option("inferschema",True).csv("dbfs:/FileStore/tables/export.csv")

# %%
df.show()
# Out:
# +---+----+---+------------+
# | id|name|age|        dept|
# +---+----+---+------------+
# |  1|   a| 30|       Sales|
# |  2|   b| 25|          IT|
# |  3|   c| 28|Data Science|
# +---+----+---+------------+

# %%
df.write.mode("overwrite").saveAsTable("test.export_table"
# Out:
#   File <command-3816955410441211>, line 1
#     df.write.mode("overwrite").saveAsTable("test.export_table"
#                                                               ^
# SyntaxError: incomplete input

# %%
# %sql
use test;
show tables;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>tableName</th><th>isTemporary</th></tr></thead><tbody><tr><td>test</td><td>demp</td><td>false</td></tr><tr><td>test</td><td>emp_table</td><td>false</td></tr><tr><td>test</td><td>export_table</td><td>false</td></tr><tr><td>test</td><td>jsonsample</td><td>false</td></tr><tr><td></td><td>display_query_1</td><td>true</td></tr><tr><td></td><td>display_query_2</td><td>true</td></tr></tbody></table></div>

# %%
# %sql
select * from export_table
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th><th>age</th><th>dept</th></tr></thead><tbody><tr><td>1</td><td>a</td><td>30</td><td>Sales</td></tr><tr><td>2</td><td>b</td><td>25</td><td>IT</td></tr><tr><td>3</td><td>c</td><td>28</td><td>Data Science</td></tr></tbody></table></div>

# %% [markdown]
# ##### Where is the metadata of these tables getting saved?

# %%
# %fs ls dbfs:/user/hive/warehouse/test.db/export_table
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/user/hive/warehouse/test.db/export_table/_delta_log/</td><td>_delta_log/</td><td>0</td><td>1695710783000</td></tr><tr><td>dbfs:/user/hive/warehouse/test.db/export_table/part-00000-7c3ce98f-39ad-4dc2-8fc3-37a5a60770fe-c000.snappy.parquet</td><td>part-00000-7c3ce98f-39ad-4dc2-8fc3-37a5a60770fe-c000.snappy.parquet</td><td>1289</td><td>1695710784000</td></tr></tbody></table></div>

# %%
# %sql 
describe detail export_table
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# there are two types of tables
# 1. managed table
# 2. external table

# %% [markdown]
# Hierarchy
# - MetaStore
# - In a metastore, Catalog1/Catalog2
# - In a catalog, Schema1/Schema2/Schema3
# - In a schema, table/view/function
# - In a table, managed/azure external

# %%
# %sql
describe extended export_table;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# ### Mounting Data

# %% [markdown]
# Mounting
# Notebook Authentication
# - Access Key (Deprecated)
# - SAS (Shared Access Key)
# - Service Principal(Recommend)

# %% [markdown]
# Syntax: dbutils.fs.mount(
#   source = "wasbs://<containername>@<storageaccount>.blob.core.windows.net",
#   mount_point = "/mnt/input",
#   extra_configs = {"fs.azure.account.key.<storageaccount>.blob.core.windows.net":dbutils.secrets.get(scope = "<scope-name>", key = "<key-name>")})

# %%
dbutils.fs.mount(
  source = "wasbs://raw@sanly.blob.core.windows.net",
  mount_point = "/mnt/sanly/raw",
  extra_configs = {"fs.azure.account.key.sanly.blob.core.windows.net":"+wZyMJdwqiETIzCNMc/uvE0AJQ/2+fIGVKKvfx4um7lsUO0EPZjLx3efLhF9OihDdkaV1TBwq77j+AStSZRQ1Q=="})
# Out:
# ---------------------------------------------------------------------------
# ExecutionError                            Traceback (most recent call last)
# File <command-1090102407335508>, line 1
# ----> 1 dbutils.fs.mount(
#       2   source = "wasbs://raw@sanly.blob.core.windows.net",
#       3   mount_point = "/mnt/sanly/raw",
#       4   extra_configs = {"fs.azure.account.key.sanly.blob.core.windows.net":"+wZyMJdwqiETIzCNMc/uvE0AJQ/2+fIGVKKvfx4um7lsUO0EPZjLx3efLhF9OihDdkaV1TBwq77j+AStSZRQ1Q=="})
#
# File /databricks/python_shell/dbruntime/dbutils.py:362, in DBUtils.FSHandler.prettify_exception_message.<locals>.f_with_exception_handling(*args, **kwargs)
#     360 exc.__context__ = None
#     361 exc.__cause__ = None
# --> 362 raise exc
#
# ExecutionError: An error occurred while calling o1370.mount.
# ...

# %%
df=spark.read.option("header",True).option("inferschema",True).csv("dbfs:/mnt/sanly/raw/Baby_Names.csv")
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# File <command-3816955410441199>, line 1
# ----> 1 df=spark.read.option("header",True).option("inferschema",True).csv("dbfs:/mnt/sanly/raw/Baby_Names.csv")
#
# File /databricks/spark/python/pyspark/instrumentation_utils.py:48, in _wrap_function.<locals>.wrapper(*args, **kwargs)
#      46 start = time.perf_counter()
#      47 try:
# ---> 48     res = func(*args, **kwargs)
#      49     logger.log_success(
#      50         module_name, class_name, function_name, time.perf_counter() - start, signature
#      51     )
#      52     return res
#
# ...

# %%
output="dbfs:/mnt/sanly/raw/output"

# %%
df.write.mode("overwrite").parquet(f"{output}/naval/babyname")
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# File <command-3816955410441197>, line 1
# ----> 1 df.write.mode("overwrite").parquet(f"{output}/naval/babyname")
#
# File /databricks/spark/python/pyspark/instrumentation_utils.py:80, in _wrap_property.<locals>.wrapper(self)
#      78 try:
#      79     if logger is None:
# ---> 80         return prop.fget(self)
#      82     start = time.perf_counter()
#      83     try:
#
# File /databricks/spark/python/pyspark/sql/dataframe.py:514, in DataFrame.write(self)
#     487 @property
#     488 def write(self) -> DataFrameWriter:
#     489     """
#     490     Interface for saving the content of the non-streaming :class:`DataFrame` out into external
#     491     storage.
#    (...)
#     512     >>> _ = spark.sql("DROP TABLE tab2")
#     513     """
# --> 514     return DataFrameWriter(self)
#
# ...

# %%
dbutils.fs.unmount("/mnt/sanly/raw")
# Out:
# ---------------------------------------------------------------------------
# ExecutionError                            Traceback (most recent call last)
# File <command-3816955410441196>, line 1
# ----> 1 dbutils.fs.unmount("/mnt/sanly/raw")
#
# File /databricks/python_shell/dbruntime/dbutils.py:362, in DBUtils.FSHandler.prettify_exception_message.<locals>.f_with_exception_handling(*args, **kwargs)
#     360 exc.__context__ = None
#     361 exc.__cause__ = None
# --> 362 raise exc
#
# ExecutionError: An error occurred while calling o1370.unmount.
# : java.rmi.RemoteException: java.lang.IllegalArgumentException: requirement failed: Directory not mounted: /mnt/sanly/raw; nested exception is:
# 	java.lang.IllegalArgumentException: requirement failed: Directory not mounted: /mnt/sanly/raw
# 	at com.databricks.backend.daemon.data.client.DbfsClient.send0(DbfsClient.scala:135)
# 	at com.databricks.backend.daemon.data.client.DbfsClient.sendIdempotent(DbfsClient.scala:69)
# ...

# %% [markdown]
# ### Real-Time Streaming

# %%
dbutils.fs.mount(
  source = "wasbs://inputfiles@saunext.blob.core.windows.net",
  mount_point = "/mnt/saunext/inputfiles",
  extra_configs = {"fs.azure.account.key.saunext.blob.core.windows.net":"UUDMjjk8JYIiTwHNyh8WCs3BShkfIL//HM/cUrbOrRmUH+HaoR/J5bM9MlWTYefbkqNo/bQzgs1M+AStEn3dkA=="})
# Out:
# ---------------------------------------------------------------------------
# ExecutionError                            Traceback (most recent call last)
# File <command-1090102407335513>, line 1
# ----> 1 dbutils.fs.mount(
#       2   source = "wasbs://inputfiles@saunext.blob.core.windows.net",
#       3   mount_point = "/mnt/saunext/inputfiles",
#       4   extra_configs = {"fs.azure.account.key.saunext.blob.core.windows.net":"UUDMjjk8JYIiTwHNyh8WCs3BShkfIL//HM/cUrbOrRmUH+HaoR/J5bM9MlWTYefbkqNo/bQzgs1M+AStEn3dkA=="})
#
# File /databricks/python_shell/dbruntime/dbutils.py:362, in DBUtils.FSHandler.prettify_exception_message.<locals>.f_with_exception_handling(*args, **kwargs)
#     360 exc.__context__ = None
#     361 exc.__cause__ = None
# --> 362 raise exc
#
# ExecutionError: An error occurred while calling o1370.mount.
# : java.rmi.RemoteException: java.lang.IllegalArgumentException: requirement failed: Directory already mounted: /mnt/saunext/inputfiles; nested exception is:
# ...

# %%
users_sch="timestamp timestamp, event_type string, user_id string, page_id string"
df=spark.readStream.schema(users_sch).json("dbfs:/mnt/saunext/inputfiles/inputstream/")
df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
outputstream="dbfs:/mnt/saunext/inputfiles/outputstream"
df.writeStream\
.option("checkpointlocation",f"{outputstream}/naval/checkpoint")\
.option("path",f"{outputstream}/Shyam/output")\
.table("test.jsonsample")

# %%
# %sql
select * from test.jsonsample
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>timestamp</th><th>event_type</th><th>user_id</th><th>page_id</th></tr></thead><tbody></tbody></table></div>

# %%
for stream in spark.streams.active:
    stream.stop()

# %%
(spark
.readStream
.schema(users_sch)
.json("dbfs:/mnt/saunext/inputfiles/inputstream/")
.writeStream
.option("checkpointlocation",f"{outputstream}/naval/checkpoint")
.option("path",f"{outputstream}/naval/output")
.trigger(once=True)
.table("test.jsonsample")
)
